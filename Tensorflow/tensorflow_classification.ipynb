# %%
#from google.colab import files
#uploaded = files.upload()

# %%
# !ls
# Out:
# insurance_data.csv  sample_data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import warnings
warnings.filterwarnings('ignore')
# read the csv file
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['sex'] = df['sex'].apply(lambda x: 0 if x == 'female' else 1)

df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
df['smoker'] = df['smoker'].apply( lambda x: 0 if x == 'no' else 1)
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
region_dummies = pd.get_dummies(df['region'], drop_first=True, dtype=int)
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
df = pd.concat([df, region_dummies], axis='columns')
df
# Out:
#       age  sex     bmi  children  smoker     region      charges  northwest  \
# 0      19    0  27.900         0       1  southwest  16884.92400          0
# 1      18    1  33.770         1       0  southeast   1725.55230          0
# 2      28    1  33.000         3       0  southeast   4449.46200          0
# 3      33    1  22.705         0       0  northwest  21984.47061          1
# 4      32    1  28.880         0       0  northwest   3866.85520          1
# ...   ...  ...     ...       ...     ...        ...          ...        ...
# 1333   50    1  30.970         3       0  northwest  10600.54830          1
# 1334   18    0  31.920         0       0  northeast   2205.98080          0
# 1335   18    0  36.850         0       0  southeast   1629.83350          0
# 1336   21    0  25.800         0       0  southwest   2007.94500          0
# 1337   61    0  29.070         0       1  northwest  29141.36030          1
#
#       southeast  southwest
# 0             0          1
# 1             1          0
# 2             1          0
# 3             0          0
# 4             0          0
# ...         ...        ...
# 1333          0          0
# 1334          0          0
# 1335          1          0
# 1336          0          1
# 1337          0          0
#
# [1338 rows x 10 columns]

# %%
df.drop(['region'], axis = 1, inplace = True)
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
X = df.drop(columns =['smoker'])
y = df['smoker']

X
# Out:
#       age  sex     bmi  children      charges  northwest  southeast  southwest
# 0      19    0  27.900         0  16884.92400          0          0          1
# 1      18    1  33.770         1   1725.55230          0          1          0
# 2      28    1  33.000         3   4449.46200          0          1          0
# 3      33    1  22.705         0  21984.47061          1          0          0
# 4      32    1  28.880         0   3866.85520          1          0          0
# ...   ...  ...     ...       ...          ...        ...        ...        ...
# 1333   50    1  30.970         3  10600.54830          1          0          0
# 1334   18    0  31.920         0   2205.98080          0          0          0
# 1335   18    0  36.850         0   1629.83350          0          1          0
# 1336   21    0  25.800         0   2007.94500          0          0          1
# 1337   61    0  29.070         0  29141.36030          1          0          0
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1338, dtype: int64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
y
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2)

# %%
N , D = X_train.shape

# %%
N , D
# Out:
# (1070, 8)

# %%
X_test.shape
# Out:
# (268, 8)

# %%
y_train.shape
# Out:
# (1070, 1)

# %%
y_train
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#y_train = scaler.fit_transform(y_train)
#y_test = scaler.transform(y_test)

# %%
y_train
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
#model = tf.keras.models.Sequential([tf.keras.layers.Input(shape=(D,)), tf.keras.layers.Dense(1, activation='sigmoid')])

#model = tf.keras.models.Sequential()
#model.add(tf.keras.layers.Dense(1, activation='sigmoid',input_shape=(D,)))
##model.add(tf.keras.layers.Dense(32, activation='relu',input_shape=(D,)))


model = keras.Sequential(
    [
     layers.Dense(10,activation="relu",input_shape=(D,)),
     layers.Dense(10,activation="relu"),
     layers.Dense(1,activation="sigmoid")
    ]
)

# %%
#Alternative
#model = tf.keras.models.Sequential()
#model.add(tf.keras.layers.Dense(1, activation='sigmoid',input_shape=(D,)))

# %% [markdown]
# **Keras Regression Metrics**
#
# •Mean Squared Error: mean_squared_error, MSE or mse
#
# •Mean Absolute Error: mean_absolute_error, MAE, mae
#
# •Mean Absolute Percentage Error: mean_absolute_percentage_error, MAPE, mape
#
# •Cosine Proximity: cosine_proximity, cosine
#
#
#
# **Keras Classification Metrics**
#
# •Binary Accuracy: binary_accuracy, acc
#
# •Categorical Accuracy: categorical_accuracy, acc
#
# •Sparse Categorical Accuracy: sparse_categorical_accuracy
#
# •Top k Categorical Accuracy: top_k_categorical_accuracy (requires you specify a k parameter)
#
# •Sparse Top k Categorical Accuracy: sparse_top_k_categorical_accuracy (requires you specify a k parameter)

# %%
#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])

#model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# For binary classification
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# For multi-class classification
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Setting an appropriate learning rate
#from keras.optimizers import Adam
#opt = Adam(learning_rate=0.001)
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
r = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)

#r = model.fit(X_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 5ms/step - loss: 0.6615 - accuracy: 0.6318 - val_loss: 0.6155 - val_accuracy: 0.7164
# Epoch 2/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5662 - accuracy: 0.7869 - val_loss: 0.5451 - val_accuracy: 0.7799
# Epoch 3/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.8009 - val_loss: 0.4806 - val_accuracy: 0.7873
# Epoch 4/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.4326 - accuracy: 0.8056 - val_loss: 0.4183 - val_accuracy: 0.8097
# Epoch 5/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.8364 - val_loss: 0.3550 - val_accuracy: 0.8731
# Epoch 6/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8841 - val_loss: 0.2979 - val_accuracy: 0.9067
# Epoch 7/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8944 - val_loss: 0.2481 - val_accuracy: 0.9291
# Epoch 8/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2316 - accuracy: 0.8981 - val_loss: 0.2110 - val_accuracy: 0.9366
# Epoch 9/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.1978 - accuracy: 0.9224 - val_loss: 0.1857 - val_accuracy: 0.9254
# Epoch 10/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.1736 - accuracy: 0.9346 - val_loss: 0.1653 - val_accuracy: 0.9366
# Epoch 11/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9449 - val_loss: 0.1532 - val_accuracy: 0.9366
# Epoch 12/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 0.9505 - val_loss: 0.1427 - val_accuracy: 0.9440
# Epoch 13/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9542 - val_loss: 0.1355 - val_accuracy: 0.9515
# Epoch 14/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9542 - val_loss: 0.1291 - val_accuracy: 0.9515
# Epoch 15/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1219 - accuracy: 0.9533 - val_loss: 0.1241 - val_accuracy: 0.9515
# Epoch 16/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1179 - accuracy: 0.9551 - val_loss: 0.1211 - val_accuracy: 0.9552
# Epoch 17/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.9542 - val_loss: 0.1168 - val_accuracy: 0.9590
# Epoch 18/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9533 - val_loss: 0.1146 - val_accuracy: 0.9590
# Epoch 19/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.9542 - val_loss: 0.1123 - val_accuracy: 0.9590
# Epoch 20/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.9570 - val_loss: 0.1106 - val_accuracy: 0.9590
# Epoch 21/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9589 - val_loss: 0.1080 - val_accuracy: 0.9590
# Epoch 22/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9589 - val_loss: 0.1075 - val_accuracy: 0.9552
# Epoch 23/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9617 - val_loss: 0.1059 - val_accuracy: 0.9552
# Epoch 24/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9570 - val_loss: 0.1055 - val_accuracy: 0.9552
# Epoch 25/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9607 - val_loss: 0.1050 - val_accuracy: 0.9552
# Epoch 26/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 0.9617 - val_loss: 0.1037 - val_accuracy: 0.9552
# Epoch 27/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9617 - val_loss: 0.1041 - val_accuracy: 0.9627
# Epoch 28/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9626 - val_loss: 0.1017 - val_accuracy: 0.9590
# Epoch 29/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9654 - val_loss: 0.1015 - val_accuracy: 0.9590
# Epoch 30/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9645 - val_loss: 0.1011 - val_accuracy: 0.9590
# Epoch 31/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9617 - val_loss: 0.1007 - val_accuracy: 0.9590
# Epoch 32/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9645 - val_loss: 0.1000 - val_accuracy: 0.9590
# Epoch 33/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9626 - val_loss: 0.1004 - val_accuracy: 0.9627
# Epoch 34/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9617 - val_loss: 0.0987 - val_accuracy: 0.9590
# Epoch 35/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9626 - val_loss: 0.0993 - val_accuracy: 0.9627
# Epoch 36/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9617 - val_loss: 0.0989 - val_accuracy: 0.9627
# Epoch 37/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9645 - val_loss: 0.0995 - val_accuracy: 0.9627
# Epoch 38/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9654 - val_loss: 0.0989 - val_accuracy: 0.9627
# Epoch 39/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9664 - val_loss: 0.0982 - val_accuracy: 0.9627
# Epoch 40/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9636 - val_loss: 0.0985 - val_accuracy: 0.9627
# Epoch 41/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9673 - val_loss: 0.0984 - val_accuracy: 0.9627
# Epoch 42/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.9654 - val_loss: 0.0981 - val_accuracy: 0.9627
# Epoch 43/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 0.9654 - val_loss: 0.0980 - val_accuracy: 0.9627
# Epoch 44/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0876 - accuracy: 0.9664 - val_loss: 0.0975 - val_accuracy: 0.9627
# Epoch 45/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9682 - val_loss: 0.0975 - val_accuracy: 0.9627
# Epoch 46/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9673 - val_loss: 0.0980 - val_accuracy: 0.9590
# Epoch 47/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9682 - val_loss: 0.0981 - val_accuracy: 0.9590
# Epoch 48/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9701 - val_loss: 0.0970 - val_accuracy: 0.9627
# Epoch 49/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9682 - val_loss: 0.0973 - val_accuracy: 0.9590
# Epoch 50/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9701 - val_loss: 0.0982 - val_accuracy: 0.9590
# Epoch 51/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9692 - val_loss: 0.0973 - val_accuracy: 0.9590
# Epoch 52/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9692 - val_loss: 0.0969 - val_accuracy: 0.9590
# Epoch 53/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.9701 - val_loss: 0.0976 - val_accuracy: 0.9590
# Epoch 54/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 0.9692 - val_loss: 0.0978 - val_accuracy: 0.9590
# Epoch 55/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9682 - val_loss: 0.0975 - val_accuracy: 0.9590
# Epoch 56/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9710 - val_loss: 0.0975 - val_accuracy: 0.9590
# Epoch 57/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9720 - val_loss: 0.0976 - val_accuracy: 0.9590
# Epoch 58/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9710 - val_loss: 0.0982 - val_accuracy: 0.9590
# Epoch 59/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9710 - val_loss: 0.0972 - val_accuracy: 0.9590
# Epoch 60/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9692 - val_loss: 0.0980 - val_accuracy: 0.9590
# Epoch 61/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 0.9720 - val_loss: 0.0978 - val_accuracy: 0.9590
# Epoch 62/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9729 - val_loss: 0.0976 - val_accuracy: 0.9590
# Epoch 63/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.9729 - val_loss: 0.0971 - val_accuracy: 0.9590
# Epoch 64/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9710 - val_loss: 0.0989 - val_accuracy: 0.9590
# Epoch 65/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9710 - val_loss: 0.0979 - val_accuracy: 0.9590
# Epoch 66/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9729 - val_loss: 0.0982 - val_accuracy: 0.9590
# Epoch 67/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9738 - val_loss: 0.0976 - val_accuracy: 0.9590
# Epoch 68/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9710 - val_loss: 0.0983 - val_accuracy: 0.9590
# Epoch 69/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9729 - val_loss: 0.0985 - val_accuracy: 0.9590
# Epoch 70/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9720 - val_loss: 0.0998 - val_accuracy: 0.9590
# Epoch 71/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9729 - val_loss: 0.0997 - val_accuracy: 0.9590
# Epoch 72/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9720 - val_loss: 0.0993 - val_accuracy: 0.9590
# Epoch 73/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9710 - val_loss: 0.0990 - val_accuracy: 0.9590
# Epoch 74/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0796 - accuracy: 0.9729 - val_loss: 0.1001 - val_accuracy: 0.9590
# Epoch 75/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9748 - val_loss: 0.1004 - val_accuracy: 0.9590
# Epoch 76/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 0.9738 - val_loss: 0.0993 - val_accuracy: 0.9590
# Epoch 77/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.9748 - val_loss: 0.0993 - val_accuracy: 0.9590
# Epoch 78/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9720 - val_loss: 0.1004 - val_accuracy: 0.9590
# Epoch 79/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9729 - val_loss: 0.1019 - val_accuracy: 0.9590
# Epoch 80/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9748 - val_loss: 0.1004 - val_accuracy: 0.9590
# Epoch 81/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9720 - val_loss: 0.1023 - val_accuracy: 0.9590
# Epoch 82/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9748 - val_loss: 0.1007 - val_accuracy: 0.9590
# Epoch 83/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9738 - val_loss: 0.1009 - val_accuracy: 0.9590
# Epoch 84/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9748 - val_loss: 0.1014 - val_accuracy: 0.9590
# Epoch 85/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9757 - val_loss: 0.1018 - val_accuracy: 0.9590
# Epoch 86/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9738 - val_loss: 0.1024 - val_accuracy: 0.9590
# Epoch 87/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9720 - val_loss: 0.1019 - val_accuracy: 0.9590
# Epoch 88/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9748 - val_loss: 0.1037 - val_accuracy: 0.9590
# Epoch 89/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9748 - val_loss: 0.1008 - val_accuracy: 0.9590
# Epoch 90/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0763 - accuracy: 0.9738 - val_loss: 0.1030 - val_accuracy: 0.9590
# Epoch 91/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9738 - val_loss: 0.1040 - val_accuracy: 0.9590
# Epoch 92/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9738 - val_loss: 0.1016 - val_accuracy: 0.9590
# Epoch 93/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9757 - val_loss: 0.1024 - val_accuracy: 0.9590
# Epoch 94/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9748 - val_loss: 0.1037 - val_accuracy: 0.9590
# Epoch 95/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9738 - val_loss: 0.1021 - val_accuracy: 0.9590
# Epoch 96/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9738 - val_loss: 0.1037 - val_accuracy: 0.9590
# Epoch 97/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9757 - val_loss: 0.1021 - val_accuracy: 0.9590
# Epoch 98/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9757 - val_loss: 0.1032 - val_accuracy: 0.9590
# Epoch 99/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9757 - val_loss: 0.1041 - val_accuracy: 0.9590
# Epoch 100/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9748 - val_loss: 0.1031 - val_accuracy: 0.9590

# %%
r.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print('Train Score:', model.evaluate(X_train, y_train))
print('Test Score:', model.evaluate(X_test, y_test))
# Out:
# 34/34 [==============================] - 0s 1ms/step - loss: 0.0726 - accuracy: 0.9757
# Train Score: [0.07264705747365952, 0.9757009148597717]
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9590
# Test Score: [0.10309164226055145, 0.9589552283287048]

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend();

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend();

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# bmi          0
# children     0
# smoker       0
# charges      0
# northwest    0
# southeast    0
# southwest    0
# dtype: int64
